# %%
import os, cv2
from PIL import Image, ImageOps
import pickle
import imutils
from tqdm import tqdm
from time import *
import numpy as np
import math
import h5py
import timeit
import pandas as pd
from random import shuffle
import matplotlib.pyplot as plt
import keras.utils
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras import backend as K
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import preprocessing 
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import glob

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
check_dir = os.getcwd() + '/drive/My Drive/'
if 'Academics' in os.listdir(check_dir): # Niraj drive
  root_dir = '/content/drive/My Drive/Academics/Sem1/682/'
else: # Anirudh drive
  root_dir = '/content/drive/My Drive/'

# %%
dataset_path = root_dir + 'CS682 Project/Final/Dataset/data_128/'
results_path = root_dir + 'CS682 Project/Final/Results/'
models_path = root_dir + 'CS682 Project/Final/Models/'

fish_path = dataset_path + 'Fish/'
bg_path = dataset_path + 'Background/'
lamprey_path = dataset_path + 'Lamprey/'

fish_img = glob.glob(f'{fish_path}*')[:]
lamprey_img = glob.glob(f'{lamprey_path}*')[:]
bg_img = glob.glob(f'{bg_path}*')[:]

print("# of Fish images :", len(fish_img))
print("# of Lamprey images :", len(lamprey_img))
print("# of Background images :", len(bg_img))
# Out:
# # of Fish images : 5081
# # of Lamprey images : 5110
# # of Background images : 2477

# %% [markdown]
# **Class labels**
#
# Background - 0 <br/>
# Fish - 1 <br/>
# Lamprey - 2

# %%
# dataset = []
# for file in bg_img:
#   dataset.append((file, 0))
# for file in fish_img:
#   dataset.append((file, 1))
# for file in lamprey_img:
#   dataset.append((file, 2))
# shuffle(dataset)

# %% [markdown]
# **Creating h5py file**

# %%
# start = time()
# hf = h5py.File(dataset_path + "Dataset 128x128.h5", "w")
# hf.create_dataset("images", data = X)
# hf.create_dataset("labels", data = y)
# hf.close()
# end = time()
# print("Time taken %.4f" % (end - start))

# %% [markdown]
# **Data Augmentation**:
#
#
# * 2 mirrors
# * 3 rotations
# * grey-scale

# %% [markdown]
# **Data Augmentation:**

# %%
def augmentData(X, y):

  X_gen, y_gen = [], []

  datagen = ImageDataGenerator(horizontal_flip = True, 
                              vertical_flip = True, 
                              featurewise_center=True,
                              featurewise_std_normalization=True)
  
  labels = np.argmax(y, axis = 1)
  fish_img, bg_img, lamprey_img = [], [], []

  # Splitting data according to classes
  for i in range(len(labels)):
    if labels[i] == 0:
      fish_img.append(X[i])
    elif labels[i] == 1:
      bg_img.append(X[i])
    else:
      lamprey_img.append(X[i])

  f = np.array(fish_img)
  b = np.array(bg_img)
  l = np.array(lamprey_img)

  # 200 indices for rotating
  ind = np.random.choice(len(f), 200)

  it = datagen.flow(f, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(0)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(0)


  it = datagen.flow(b, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(1)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(1)

  it = datagen.flow(l, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(2)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(2)

  return np.array(X_gen), np.array(y_gen)

# %%
def sampleDataset(X, y, fraction):
  bg, fish, lamprey = [], [], []

  for img, label in zip(X, y):
    label = np.argmax(label, axis = 0)
    if label==0:
      bg.append((img, label))
    if label==1:
      fish.append((img, label))
    if label==2:
      lamprey.append((img, label))

  fraction = 0.8

  smol_X = []
  smol_y = []

  fish_ind = np.random.choice(len(fish), int(fraction*len(fish)))
  for ind in fish_ind:
      smol_X.append(fish[ind][0])
      smol_y.append(fish[ind][1])

  lamprey_ind = np.random.choice(len(lamprey), int(fraction*len(lamprey)))
  for ind in lamprey_ind:
      smol_X.append(lamprey[ind][0])
      smol_y.append(lamprey[ind][1])

  for img, label in bg:
    smol_X.append(img)
    smol_y.append(label)

  smol_y = to_categorical(smol_y)

  return np.array(smol_X), np.array(smol_y)

# %%
def load_data(data_augmentation = False, rgb2gray = False, normalize = False, fraction = 1.0):
  ''' Function to load data
  Input: Optional parameters to augment data
  Output: Returns tuple containg X_train, y_train, X_test, y_test '''

  # Reading the .h5 file
  start = time() 
  hf = h5py.File(dataset_path + "Dataset 128x128.h5", "r")
  X = np.array(hf['images']) 
  y = np.array(hf['labels']) 
  end = time() 
  hf.close() 
  print("\nTotal time taken to read %d images = %.4f seconds" % (len(X), end - start))

  if fraction < 1.0:
    X, y = sampleDataset(X, y, fraction)

  mean_pixel, std_pixel = None, None
  
  if normalize == True:
    # normalize the data by subtracting mean and dividing by std
    mean_pixel = X.mean(axis=(0, 1, 2), keepdims=True)
    std_pixel = X.std(axis=(0, 1, 2), keepdims=True)
    X = (X - mean_pixel) / std_pixel

  if data_augmentation == True: 
    start = time() 
    X_gen, y_gen = augmentData(X, y) 
    y_gen = to_categorical(y_gen)
    end = time() 
    print("\nTotal time taken to augment %d images = %.4f seconds" % (len(X), end - start)) 
    X = np.concatenate((X, X_gen)) 
    y = np.concatenate((y, y_gen))
  
  if rgb2gray == True:
    X, y = rgbGray(X, y)
    X = X[ : , : , : , np.newaxis]
    
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 158)

  print("\nDimensions of training data : ", X_train.shape, y_train.shape) 
  print("\nDimensions of test data : ", X_test.shape, y_test.shape)

  return X_train, y_train, X_test, y_test, mean_pixel, std_pixel

# %% [markdown]
# **Loading Dataset**

# %%
X_train, y_train, X_test, y_test, mean_pixel, std_pixel = load_data(normalize = True, fraction = 0.8)
# Out:
# Total time taken to read 12668 images = 119.2306 seconds
#
# Dimensions of training data :  (7971, 128, 128, 3) (7971, 3)
#
# Dimensions of test data :  (2658, 128, 128, 3) (2658, 3)

# %%
input_shape = (128, 128, 3)

model = Sequential(name = 'baseline_128x128')

model.add(Conv2D(32, (5, 5), input_shape = input_shape, padding = 'same', kernel_initializer = keras.initializers.lecun_uniform(seed = 158)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Conv2D(64, (5, 5), input_shape = input_shape, padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Conv2D(128, (5, 5), padding = 'same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Flatten())

model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=8e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "baseline_128x128"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      2432
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       204928
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 98307
# =================================================================
# Total params: 357,187
# Trainable params: 357,059
# Non-trainable params: 128
# _________________________________________________________________

# %%
checkpointer = keras.callbacks.ModelCheckpoint(models_path + 'LampNet_Baseline3_1(cb)_128x128.h5', 
                                               monitor='val_loss', verbose=1, 
                                               save_best_only=True, 
                                               save_weights_only=False, 
                                               mode='auto', period=1)

history = model.fit(X_train, y_train, batch_size = 128, epochs = 100, validation_split=0.2, shuffle = True, callbacks = [checkpointer])
model.save(models_path + 'LampNet_Baseline3_1_128x128.h5')

# creating h5py file
start = time()
hf = h5py.File(results_path + "hunt2.h5", "w")
hf.create_dataset("acc", data = history.history['acc'])
hf.create_dataset("loss", data = history.history['loss'])
hf.create_dataset("val_acc", data = history.history['val_acc'])
hf.create_dataset("val_loss", data = history.history['val_loss'])
hf.close()
end = time()
print("Saved training history!")
# Out:
# Train on 6376 samples, validate on 1595 samples
# Epoch 1/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.8173 - acc: 0.6509 - val_loss: 0.6412 - val_acc: 0.7285
#
# Epoch 00001: val_loss improved from inf to 0.64123, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 2/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.5424 - acc: 0.7787 - val_loss: 0.5516 - val_acc: 0.7498
#
# Epoch 00002: val_loss improved from 0.64123 to 0.55156, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 3/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.4244 - acc: 0.8267 - val_loss: 0.3990 - val_acc: 0.8401
#
# Epoch 00003: val_loss improved from 0.55156 to 0.39897, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 4/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.3747 - acc: 0.8444 - val_loss: 0.3586 - val_acc: 0.8495
#
# Epoch 00004: val_loss improved from 0.39897 to 0.35862, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 5/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.3358 - acc: 0.8662 - val_loss: 0.3375 - val_acc: 0.8727
#
# Epoch 00005: val_loss improved from 0.35862 to 0.33754, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 6/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.3029 - acc: 0.8863 - val_loss: 0.3150 - val_acc: 0.8815
#
# Epoch 00006: val_loss improved from 0.33754 to 0.31495, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 7/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.2943 - acc: 0.8857 - val_loss: 0.3496 - val_acc: 0.8357
#
# Epoch 00007: val_loss did not improve from 0.31495
# Epoch 8/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.2653 - acc: 0.9001 - val_loss: 0.2636 - val_acc: 0.9009
#
# Epoch 00008: val_loss improved from 0.31495 to 0.26355, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 9/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.2430 - acc: 0.9109 - val_loss: 0.2811 - val_acc: 0.8865
#
# Epoch 00009: val_loss did not improve from 0.26355
# Epoch 10/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.2239 - acc: 0.9175 - val_loss: 0.2592 - val_acc: 0.9060
#
# Epoch 00010: val_loss improved from 0.26355 to 0.25916, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 11/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.2143 - acc: 0.9199 - val_loss: 0.2610 - val_acc: 0.9060
#
# Epoch 00011: val_loss did not improve from 0.25916
# Epoch 12/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.2120 - acc: 0.9200 - val_loss: 0.2339 - val_acc: 0.9191
#
# Epoch 00012: val_loss improved from 0.25916 to 0.23395, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 13/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.1782 - acc: 0.9373 - val_loss: 0.2302 - val_acc: 0.9172
#
# Epoch 00013: val_loss improved from 0.23395 to 0.23020, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 14/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.1657 - acc: 0.9412 - val_loss: 0.2046 - val_acc: 0.9367
#
# Epoch 00014: val_loss improved from 0.23020 to 0.20462, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 15/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.1662 - acc: 0.9420 - val_loss: 0.2043 - val_acc: 0.9285
#
# Epoch 00015: val_loss improved from 0.20462 to 0.20425, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 16/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.1585 - acc: 0.9456 - val_loss: 0.1963 - val_acc: 0.9367
#
# Epoch 00016: val_loss improved from 0.20425 to 0.19625, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 17/100
# 6376/6376 [==============================] - 70s 11ms/step - loss: 0.1433 - acc: 0.9519 - val_loss: 0.1893 - val_acc: 0.9317
#
# Epoch 00017: val_loss improved from 0.19625 to 0.18934, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 18/100
# 6376/6376 [==============================] - 69s 11ms/step - loss: 0.1377 - acc: 0.9547 - val_loss: 0.1831 - val_acc: 0.9348
#
# Epoch 00018: val_loss improved from 0.18934 to 0.18311, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 19/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.1289 - acc: 0.9584 - val_loss: 0.1845 - val_acc: 0.9392
#
# Epoch 00019: val_loss did not improve from 0.18311
# Epoch 20/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.1443 - acc: 0.9465 - val_loss: 0.1898 - val_acc: 0.9298
#
# Epoch 00020: val_loss did not improve from 0.18311
# Epoch 21/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.1202 - acc: 0.9595 - val_loss: 0.1831 - val_acc: 0.9342
#
# Epoch 00021: val_loss did not improve from 0.18311
# Epoch 22/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.1183 - acc: 0.9619 - val_loss: 0.1943 - val_acc: 0.9317
#
# Epoch 00022: val_loss did not improve from 0.18311
# Epoch 23/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.1229 - acc: 0.9562 - val_loss: 0.1704 - val_acc: 0.9442
#
# Epoch 00023: val_loss improved from 0.18311 to 0.17036, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 24/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.1145 - acc: 0.9609 - val_loss: 0.1791 - val_acc: 0.9342
#
# Epoch 00024: val_loss did not improve from 0.17036
# Epoch 25/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.1022 - acc: 0.9693 - val_loss: 0.1692 - val_acc: 0.9417
#
# Epoch 00025: val_loss improved from 0.17036 to 0.16920, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 26/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.1123 - acc: 0.9617 - val_loss: 0.1629 - val_acc: 0.9505
#
# Epoch 00026: val_loss improved from 0.16920 to 0.16294, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 27/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1013 - acc: 0.9663 - val_loss: 0.1740 - val_acc: 0.9404
#
# Epoch 00027: val_loss did not improve from 0.16294
# Epoch 28/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.1012 - acc: 0.9668 - val_loss: 0.1677 - val_acc: 0.9392
#
# Epoch 00028: val_loss did not improve from 0.16294
# Epoch 29/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0894 - acc: 0.9699 - val_loss: 0.1732 - val_acc: 0.9367
#
# Epoch 00029: val_loss did not improve from 0.16294
# Epoch 30/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0823 - acc: 0.9744 - val_loss: 0.1643 - val_acc: 0.9448
#
# Epoch 00030: val_loss did not improve from 0.16294
# Epoch 31/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0793 - acc: 0.9768 - val_loss: 0.1478 - val_acc: 0.9524
#
# Epoch 00031: val_loss improved from 0.16294 to 0.14784, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 32/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0794 - acc: 0.9758 - val_loss: 0.1533 - val_acc: 0.9498
#
# Epoch 00032: val_loss did not improve from 0.14784
# Epoch 33/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0743 - acc: 0.9782 - val_loss: 0.1955 - val_acc: 0.9317
#
# Epoch 00033: val_loss did not improve from 0.14784
# Epoch 34/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0741 - acc: 0.9788 - val_loss: 0.1668 - val_acc: 0.9379
#
# Epoch 00034: val_loss did not improve from 0.14784
# Epoch 35/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0733 - acc: 0.9776 - val_loss: 0.1799 - val_acc: 0.9442
#
# Epoch 00035: val_loss did not improve from 0.14784
# Epoch 36/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0704 - acc: 0.9793 - val_loss: 0.1678 - val_acc: 0.9404
#
# Epoch 00036: val_loss did not improve from 0.14784
# Epoch 37/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.0626 - acc: 0.9820 - val_loss: 0.1566 - val_acc: 0.9442
#
# Epoch 00037: val_loss did not improve from 0.14784
# Epoch 38/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.0628 - acc: 0.9812 - val_loss: 0.1530 - val_acc: 0.9505
#
# Epoch 00038: val_loss did not improve from 0.14784
# Epoch 39/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0667 - acc: 0.9787 - val_loss: 0.1513 - val_acc: 0.9473
#
# Epoch 00039: val_loss did not improve from 0.14784
# Epoch 40/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0557 - acc: 0.9856 - val_loss: 0.1678 - val_acc: 0.9404
#
# Epoch 00040: val_loss did not improve from 0.14784
# Epoch 41/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0609 - acc: 0.9835 - val_loss: 0.1504 - val_acc: 0.9492
#
# Epoch 00041: val_loss did not improve from 0.14784
# Epoch 42/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0525 - acc: 0.9876 - val_loss: 0.1454 - val_acc: 0.9505
#
# Epoch 00042: val_loss improved from 0.14784 to 0.14541, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 43/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0597 - acc: 0.9827 - val_loss: 0.1449 - val_acc: 0.9555
#
# Epoch 00043: val_loss improved from 0.14541 to 0.14487, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 44/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0543 - acc: 0.9864 - val_loss: 0.1384 - val_acc: 0.9549
#
# Epoch 00044: val_loss improved from 0.14487 to 0.13842, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 45/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0483 - acc: 0.9879 - val_loss: 0.1435 - val_acc: 0.9517
#
# Epoch 00045: val_loss did not improve from 0.13842
# Epoch 46/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0467 - acc: 0.9886 - val_loss: 0.1461 - val_acc: 0.9517
#
# Epoch 00046: val_loss did not improve from 0.13842
# Epoch 47/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0448 - acc: 0.9887 - val_loss: 0.1419 - val_acc: 0.9549
#
# Epoch 00047: val_loss did not improve from 0.13842
# Epoch 48/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0419 - acc: 0.9896 - val_loss: 0.1544 - val_acc: 0.9492
#
# Epoch 00048: val_loss did not improve from 0.13842
# Epoch 49/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0415 - acc: 0.9900 - val_loss: 0.1400 - val_acc: 0.9567
#
# Epoch 00049: val_loss did not improve from 0.13842
# Epoch 50/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0557 - acc: 0.9835 - val_loss: 0.1468 - val_acc: 0.9561
#
# Epoch 00050: val_loss did not improve from 0.13842
# Epoch 51/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0424 - acc: 0.9906 - val_loss: 0.1389 - val_acc: 0.9524
#
# Epoch 00051: val_loss did not improve from 0.13842
# Epoch 52/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0432 - acc: 0.9886 - val_loss: 0.1864 - val_acc: 0.9254
#
# Epoch 00052: val_loss did not improve from 0.13842
# Epoch 53/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0396 - acc: 0.9903 - val_loss: 0.1424 - val_acc: 0.9498
#
# Epoch 00053: val_loss did not improve from 0.13842
# Epoch 54/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0389 - acc: 0.9909 - val_loss: 0.1506 - val_acc: 0.9511
#
# Epoch 00054: val_loss did not improve from 0.13842
# Epoch 55/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0426 - acc: 0.9889 - val_loss: 0.1450 - val_acc: 0.9555
#
# Epoch 00055: val_loss did not improve from 0.13842
# Epoch 56/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0337 - acc: 0.9928 - val_loss: 0.1439 - val_acc: 0.9549
#
# Epoch 00056: val_loss did not improve from 0.13842
# Epoch 57/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0318 - acc: 0.9936 - val_loss: 0.1337 - val_acc: 0.9599
#
# Epoch 00057: val_loss improved from 0.13842 to 0.13372, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 58/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0292 - acc: 0.9940 - val_loss: 0.1370 - val_acc: 0.9586
#
# Epoch 00058: val_loss did not improve from 0.13372
# Epoch 59/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0288 - acc: 0.9936 - val_loss: 0.1444 - val_acc: 0.9567
#
# Epoch 00059: val_loss did not improve from 0.13372
# Epoch 60/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0271 - acc: 0.9953 - val_loss: 0.1480 - val_acc: 0.9505
#
# Epoch 00060: val_loss did not improve from 0.13372
# Epoch 61/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0275 - acc: 0.9942 - val_loss: 0.1440 - val_acc: 0.9618
#
# Epoch 00061: val_loss did not improve from 0.13372
# Epoch 62/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0284 - acc: 0.9944 - val_loss: 0.1455 - val_acc: 0.9524
#
# Epoch 00062: val_loss did not improve from 0.13372
# Epoch 63/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0254 - acc: 0.9953 - val_loss: 0.1448 - val_acc: 0.9586
#
# Epoch 00063: val_loss did not improve from 0.13372
# Epoch 64/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0220 - acc: 0.9969 - val_loss: 0.1374 - val_acc: 0.9624
#
# Epoch 00064: val_loss did not improve from 0.13372
# Epoch 65/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0260 - acc: 0.9950 - val_loss: 0.1416 - val_acc: 0.9574
#
# Epoch 00065: val_loss did not improve from 0.13372
# Epoch 66/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0229 - acc: 0.9959 - val_loss: 0.1428 - val_acc: 0.9611
#
# Epoch 00066: val_loss did not improve from 0.13372
# Epoch 67/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0222 - acc: 0.9970 - val_loss: 0.1631 - val_acc: 0.9486
#
# Epoch 00067: val_loss did not improve from 0.13372
# Epoch 68/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0260 - acc: 0.9940 - val_loss: 0.1475 - val_acc: 0.9536
#
# Epoch 00068: val_loss did not improve from 0.13372
# Epoch 69/100
# 6376/6376 [==============================] - 67s 10ms/step - loss: 0.0220 - acc: 0.9962 - val_loss: 0.1426 - val_acc: 0.9586
#
# Epoch 00069: val_loss did not improve from 0.13372
# Epoch 70/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0186 - acc: 0.9972 - val_loss: 0.1440 - val_acc: 0.9536
#
# Epoch 00070: val_loss did not improve from 0.13372
# Epoch 71/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0182 - acc: 0.9975 - val_loss: 0.1392 - val_acc: 0.9599
#
# Epoch 00071: val_loss did not improve from 0.13372
# Epoch 72/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0169 - acc: 0.9986 - val_loss: 0.1332 - val_acc: 0.9630
#
# Epoch 00072: val_loss improved from 0.13372 to 0.13322, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline3_1(cb)_128x128.h5
# Epoch 73/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0170 - acc: 0.9986 - val_loss: 0.1424 - val_acc: 0.9605
#
# Epoch 00073: val_loss did not improve from 0.13322
# Epoch 74/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0145 - acc: 0.9991 - val_loss: 0.1397 - val_acc: 0.9611
#
# Epoch 00074: val_loss did not improve from 0.13322
# Epoch 75/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0158 - acc: 0.9984 - val_loss: 0.1383 - val_acc: 0.9624
#
# Epoch 00075: val_loss did not improve from 0.13322
# Epoch 76/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0204 - acc: 0.9958 - val_loss: 0.1423 - val_acc: 0.9599
#
# Epoch 00076: val_loss did not improve from 0.13322
# Epoch 77/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0200 - acc: 0.9964 - val_loss: 0.1490 - val_acc: 0.9624
#
# Epoch 00077: val_loss did not improve from 0.13322
# Epoch 78/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0155 - acc: 0.9986 - val_loss: 0.1334 - val_acc: 0.9643
#
# Epoch 00078: val_loss did not improve from 0.13322
# Epoch 79/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0137 - acc: 0.9980 - val_loss: 0.1463 - val_acc: 0.9599
#
# Epoch 00079: val_loss did not improve from 0.13322
# Epoch 80/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0135 - acc: 0.9987 - val_loss: 0.1454 - val_acc: 0.9605
#
# Epoch 00080: val_loss did not improve from 0.13322
# Epoch 81/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0114 - acc: 0.9989 - val_loss: 0.1440 - val_acc: 0.9630
#
# Epoch 00081: val_loss did not improve from 0.13322
# Epoch 82/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0146 - acc: 0.9983 - val_loss: 0.1752 - val_acc: 0.9555
#
# Epoch 00082: val_loss did not improve from 0.13322
# Epoch 83/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0115 - acc: 0.9994 - val_loss: 0.1432 - val_acc: 0.9630
#
# Epoch 00083: val_loss did not improve from 0.13322
# Epoch 84/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0103 - acc: 0.9995 - val_loss: 0.1398 - val_acc: 0.9655
#
# Epoch 00084: val_loss did not improve from 0.13322
# Epoch 85/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0109 - acc: 0.9995 - val_loss: 0.1501 - val_acc: 0.9567
#
# Epoch 00085: val_loss did not improve from 0.13322
# Epoch 86/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0088 - acc: 0.9998 - val_loss: 0.1609 - val_acc: 0.9549
#
# Epoch 00086: val_loss did not improve from 0.13322
# Epoch 87/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0095 - acc: 0.9997 - val_loss: 0.1454 - val_acc: 0.9636
#
# Epoch 00087: val_loss did not improve from 0.13322
# Epoch 88/100
# 6376/6376 [==============================] - 68s 11ms/step - loss: 0.0090 - acc: 1.0000 - val_loss: 0.1509 - val_acc: 0.9636
#
# Epoch 00088: val_loss did not improve from 0.13322
# Epoch 89/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0129 - acc: 0.9983 - val_loss: 0.1388 - val_acc: 0.9630
#
# Epoch 00089: val_loss did not improve from 0.13322
# Epoch 90/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0090 - acc: 0.9995 - val_loss: 0.1408 - val_acc: 0.9630
#
# Epoch 00090: val_loss did not improve from 0.13322
# Epoch 91/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 0.1435 - val_acc: 0.9618
#
# Epoch 00091: val_loss did not improve from 0.13322
# Epoch 92/100
# 6376/6376 [==============================] - 67s 11ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.1486 - val_acc: 0.9611
#
# Epoch 00092: val_loss did not improve from 0.13322
# Epoch 93/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0064 - acc: 0.9998 - val_loss: 0.1399 - val_acc: 0.9643
#
# Epoch 00093: val_loss did not improve from 0.13322
# Epoch 94/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0067 - acc: 0.9998 - val_loss: 0.1550 - val_acc: 0.9611
#
# Epoch 00094: val_loss did not improve from 0.13322
# Epoch 95/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.1400 - val_acc: 0.9630
#
# Epoch 00095: val_loss did not improve from 0.13322
# Epoch 96/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.1495 - val_acc: 0.9636
#
# Epoch 00096: val_loss did not improve from 0.13322
# Epoch 97/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0065 - acc: 0.9998 - val_loss: 0.1627 - val_acc: 0.9574
#
# Epoch 00097: val_loss did not improve from 0.13322
# Epoch 98/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 0.1469 - val_acc: 0.9636
#
# Epoch 00098: val_loss did not improve from 0.13322
# Epoch 99/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.1504 - val_acc: 0.9630
#
# Epoch 00099: val_loss did not improve from 0.13322
# Epoch 100/100
# 6376/6376 [==============================] - 66s 10ms/step - loss: 0.0046 - acc: 1.0000 - val_loss: 0.1508 - val_acc: 0.9630
#
# Epoch 00100: val_loss did not improve from 0.13322
# Saved training history!

# %%
print("Best val_loss = {}\nBest val_acc = {}".format(min(history.history['val_loss']), max(history.history['val_acc'])))
# Out:
# Best val_loss = 0.13322294180669755
# Best val_acc = 0.9655172417903769

# %%
title_font = {'fontname':'Times', 'size':'16', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} # Bottom vertical alignment for more space
axis_font = {'fontname':'Times', 'size':'14'}
 
 
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy', **title_font)
plt.ylabel('accuracy', **axis_font)
plt.xlabel('epoch', **axis_font)
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# plt.savefig(results_path + 'Accuracy plot.pdf')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', **title_font)
plt.ylabel('loss', **axis_font)
plt.xlabel('epoch', **axis_font)
plt.legend(['train', 'val'], loc='upper right')
plt.show()
# plt.savefig(results_path + 'Loss plot.pdf')
# Out:
# findfont: Font family ['Times'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times'] not found. Falling back to DejaVu Sans.
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
print("############### Stats for fully trained model ###############")
model = load_model(models_path + 'LampNet_Baseline3_1_128x128.h5')

test_scores = model.evaluate(X_test, y_test, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
y_preds1 = model.predict(X_test)
ctest, preds = np.argmax(y_test, axis = 1), np.argmax(y_preds1, axis = 1)
print("Confusion matrix : ")
print(confusion_matrix(ctest, preds))

print("############### Stats for CallBack model ###############")
model = load_model(models_path + 'LampNet_Baseline3_1(cb)_128x128.h5')

test_scores = model.evaluate(X_test, y_test, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
y_preds2 = model.predict(X_test)
ctest, preds = np.argmax(y_test, axis = 1), np.argmax(y_preds2, axis = 1)
print("Confusion matrix : ")
print(confusion_matrix(ctest, preds))
# Out:
# ############### Stats for fully trained model ###############
# Test loss: 0.16002099006033824
# Test accuracy: 0.963882618510158
# Confusion matrix :
# [[639   7   6]
#  [ 27 942  14]
#  [ 27  15 981]]
# ############### Stats for CallBack model ###############
# Test loss: 0.14671910237422825
# Test accuracy: 0.964635063957863
# Confusion matrix :
# [[634   7  11]
#  [ 24 943  16]
#  [ 22  14 987]]

# %%
y_preds1 = np.argmax(y_preds1, axis = 1)
y_preds2 = np.argmax(y_preds2, axis = 1)
y_test = np.argmax(y_test, axis = 1)

# %%
print("############### Classification report for Fully trained model ###############")
print(classification_report(y_test, y_preds1, target_names = ['Background', 'Fish', 'Lamprey']) )

print("############### Classification report for CallBack model ###############")
print(classification_report(y_test, y_preds2, target_names = ['Background', 'Fish', 'Lamprey']) )
# Out:
# ############### Classification report for Fully trained model ###############
#               precision    recall  f1-score   support
#
#   Background       0.92      0.98      0.95       652
#         Fish       0.98      0.96      0.97       983
#      Lamprey       0.98      0.96      0.97      1023
#
#     accuracy                           0.96      2658
#    macro avg       0.96      0.97      0.96      2658
# weighted avg       0.96      0.96      0.96      2658
#
# ############### Classification report for CallBack model ###############
#               precision    recall  f1-score   support
#
#   Background       0.93      0.97      0.95       652
#         Fish       0.98      0.96      0.97       983
#      Lamprey       0.97      0.96      0.97      1023
#
#     accuracy                           0.96      2658
#    macro avg       0.96      0.97      0.96      2658
# weighted avg       0.97      0.96      0.96      2658

# %%
y_probs = model.predict_proba(X_test)
y_test = to_categorical(y_test)

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

fpr = dict()
tpr = dict()
roc_auc = dict()
class_score = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    class_score[i] = roc_auc_score(y_test[:, i], y_probs[:, i])
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure(figsize=(10, 7))
lw = 2
plt.plot(fpr[2], tpr[2], color='orange',
         lw=lw, label='ROC curve for Lamprey class(area = %0.2f)' % roc_auc[2])
plt.plot(fpr[1], tpr[1], color='red',
         lw=lw, label='ROC curve for Fish class (area = %0.2f)' % roc_auc[1])
plt.plot(fpr[0], tpr[0], color='green',
         lw=lw, label='ROC curve Background class(area = %0.2f)' % roc_auc[0])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', family = 'sans-serif', size = 18)
plt.ylabel('True Positive Rate',  family = 'sans-serif', size = 18)
plt.title('ROC curve for each class', family = 'serif', size = 20, weight = 'normal')
plt.xticks(family = 'sans-serif', size = 16)
plt.yticks(family = 'sans-serif', size = 16)
plt.legend(loc="lower right", prop={'size': 17})
plt.show()
print(class_score)
# Out:
# {0: 0.991575121261981, 1: 0.9934559147295061, 2: 0.9942574606676412}

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(10,7)})
sns.lineplot(fpr[2], tpr[2], color='orange',
         lw=lw, label='ROC curve for Lamprey class(area = %0.2f)' % roc_auc[2])
sns.lineplot( fpr[1], tpr[1], color='red',
         lw=lw, label='ROC curve for Fish class (area = %0.2f)' % roc_auc[1])
sns.lineplot(fpr[0], tpr[0], color='green',
         lw=lw, label='ROC curve Background class(area = %0.2f)' % roc_auc[0])
sns.lineplot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.legend(loc="lower right", prop={'size': 17})
plt.xlabel('False Positive Rate', family = 'sans-serif', size = 18)
plt.ylabel('True Positive Rate',  family = 'sans-serif', size = 18)
plt.title('ROC curve for each class', family = 'serif', size = 20, weight = 'normal')
plt.xticks(family = 'sans-serif', size = 16)
plt.yticks(family = 'sans-serif', size = 16)
# ax.xlim([0.0, 1.0])
# ax.ylim([0.0, 1.05])
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text yticklabel objects>)

# %%
print("ROC-AUC score for the model %.3f" %(roc_auc_score(y_test, y_probs)))
# Out:
# ROC-AUC score for the model 0.993
