# %%
import os, cv2
from PIL import Image, ImageOps
import pickle
import imutils
from tqdm import tqdm
from time import *
import numpy as np
import math
import h5py
import timeit
from random import shuffle
import matplotlib.pyplot as plt
import keras.utils
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras import backend as K
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import preprocessing 
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import glob

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
check_dir = os.getcwd() + '/drive/My Drive/'
if 'Academics' in os.listdir(check_dir): # Niraj drive
  root_dir = '/content/drive/My Drive/Academics/Sem1/682/'
else: # Anirudh drive
  root_dir = '/content/drive/My Drive/'

# %%
dataset_path = root_dir + 'CS682 Project/Final/Dataset/data_128/'
results_path = root_dir + 'CS682 Project/Final/Results/'
models_path = root_dir + 'CS682 Project/Final/Models/'

fish_path = dataset_path + 'Fish/'
bg_path = dataset_path + 'Background/'
lamprey_path = dataset_path + 'Lamprey/'

fish_img = glob.glob(f'{fish_path}*')[:]
lamprey_img = glob.glob(f'{lamprey_path}*')[:]
bg_img = glob.glob(f'{bg_path}*')[:]

print("# of Fish images :", len(fish_img))
print("# of Lamprey images :", len(lamprey_img))
print("# of Background images :", len(bg_img))
# Out:
# # of Fish images : 5081
# # of Lamprey images : 5110
# # of Background images : 2477

# %% [markdown]
# **Class labels**
#
# Background - 0 <br/>
# Fish - 1 <br/>
# Lamprey - 2

# %% [markdown]
# **Data Augmentation**:
#
#
# * 2 mirrors
# * 3 rotations
# * grey-scale

# %% [markdown]
# **Data Augmentation:**

# %%
def augmentData(X, y):

  X_gen, y_gen = [], []

  datagen = ImageDataGenerator(horizontal_flip = True, 
                              vertical_flip = True, 
                              featurewise_center=True,
                              featurewise_std_normalization=True)
  
  labels = np.argmax(y, axis = 1)
  fish_img, bg_img, lamprey_img = [], [], []

  # Splitting data according to classes
  for i in range(len(labels)):
    if labels[i] == 0:
      fish_img.append(X[i])
    elif labels[i] == 1:
      bg_img.append(X[i])
    else:
      lamprey_img.append(X[i])

  f = np.array(fish_img)
  b = np.array(bg_img)
  l = np.array(lamprey_img)

  # 200 indices for rotating
  ind = np.random.choice(len(f), 200)

  it = datagen.flow(f, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(0)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(0)


  it = datagen.flow(b, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(1)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(1)

  it = datagen.flow(l, batch_size = 128)
  for i in range(5):
    batch = it.next()
    for j in range(len(batch)):
      img = batch[j].astype('float')
      X_gen.append(img)
      y_gen.append(2)
  for index in ind:
    X_gen.append(np.rot90(X[index], k = index%3 + 1, axes = (0, 1)))
    y_gen.append(2)

  return np.array(X_gen), np.array(y_gen)

# %%
def sampleDataset(X, y, fraction):
  bg, fish, lamprey = [], [], []

  for img, label in zip(X, y):
    label = np.argmax(label, axis = 0)
    if label==0:
      bg.append((img, label))
    if label==1:
      fish.append((img, label))
    if label==2:
      lamprey.append((img, label))

  fraction = 0.8

  smol_X = []
  smol_y = []

  fish_ind = np.random.choice(len(fish), int(fraction*len(fish)))
  for ind in fish_ind:
      smol_X.append(fish[ind][0])
      smol_y.append(fish[ind][1])

  lamprey_ind = np.random.choice(len(lamprey), int(fraction*len(lamprey)))
  for ind in lamprey_ind:
      smol_X.append(lamprey[ind][0])
      smol_y.append(lamprey[ind][1])

  for img, label in bg:
    smol_X.append(img)
    smol_y.append(label)

  smol_y = to_categorical(smol_y)

  return np.array(smol_X), np.array(smol_y)

# %%
def load_data(data_augmentation = False, rgb2gray = False, normalize = False, fraction = 1.0):
  ''' Function to load data
  Input: Optional parameters to augment data
  Output: Returns tuple containg X_train, y_train, X_test, y_test '''

  # Reading the .h5 file
  start = time() 
  hf = h5py.File(dataset_path + "Dataset 128x128.h5", "r")
  X = np.array(hf['images']) 
  y = np.array(hf['labels']) 
  end = time() 
  hf.close() 
  print("\nTotal time taken to read %d images = %.4f seconds" % (len(X), end - start))

  if fraction < 1.0:
    X, y = sampleDataset(X, y, fraction)

  mean_pixel, std_pixel = None, None
  
  if normalize == True:
    # normalize the data by subtracting mean and dividing by std
    mean_pixel = X.mean(axis=(0, 1, 2), keepdims=True)
    std_pixel = X.std(axis=(0, 1, 2), keepdims=True)
    X = (X - mean_pixel) / std_pixel

  if data_augmentation == True: 
    start = time() 
    X_gen, y_gen = augmentData(X, y) 
    y_gen = to_categorical(y_gen)
    end = time() 
    print("\nTotal time taken to augment %d images = %.4f seconds" % (len(X), end - start)) 
    X = np.concatenate((X, X_gen)) 
    y = np.concatenate((y, y_gen))
  
  if rgb2gray == True:
    X, y = rgbGray(X, y)
    X = X[ : , : , : , np.newaxis]
    
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, shuffle = True, random_state = 158)

  print("\nDimensions of training data : ", X_train.shape, y_train.shape) 
  print("\nDimensions of test data : ", X_test.shape, y_test.shape)

  return X_train, y_train, X_test, y_test, mean_pixel, std_pixel

# %% [markdown]
# **Loading Dataset**

# %%
X_train, y_train, X_test, y_test, mean_pixel, std_pixel = load_data(normalize = True, fraction = 0.8)
# Out:
# Total time taken to read 12668 images = 124.0483 seconds
#
# Dimensions of training data :  (7971, 128, 128, 3) (7971, 3)
#
# Dimensions of test data :  (2658, 128, 128, 3) (2658, 3)

# %%
input_shape = (128, 128, 3)

model = Sequential(name = 'baseline_128x128')

model.add(Conv2D(32, (5, 5), input_shape = input_shape, padding = 'same', kernel_initializer = keras.initializers.lecun_uniform(seed = 158)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Conv2D(64, (5, 5), input_shape = input_shape, padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Conv2D(128, (5, 5), padding = 'same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))

model.add(Flatten())

model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=8e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "baseline_128x128"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      2432
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       204928
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 98307
# =================================================================
# Total params: 357,187
# Trainable params: 357,059
# Non-trainable params: 128
# _________________________________________________________________

# %%
checkpointer = keras.callbacks.ModelCheckpoint(models_path + 'LampNet_Baseline5_1(cb)_128x128.h5', 
                                               monitor='val_loss', verbose=1, 
                                               save_best_only=True, 
                                               save_weights_only=False, 
                                               mode='auto', period=1)

history = model.fit(X_train, y_train, batch_size = 128, epochs = 100, validation_split=0.2, shuffle = True, callbacks = [checkpointer])
model.save(models_path + 'LampNet_Baseline5_1_128x128.h5')

# Saving history
start = time()
hf = h5py.File(results_path + "hunt3.h5", "w")
hf.create_dataset("acc", data = history.history['acc'])
hf.create_dataset("loss", data = history.history['loss'])
hf.create_dataset("val_acc", data = history.history['val_acc'])
hf.create_dataset("val_loss", data = history.history['val_loss'])
hf.close()
end = time()
print("Saved training history!")
# Out:
# Train on 6376 samples, validate on 1595 samples
# Epoch 1/100
# 6376/6376 [==============================] - 76s 12ms/step - loss: 0.8034 - acc: 0.6586 - val_loss: 0.6571 - val_acc: 0.7166
#
# Epoch 00001: val_loss improved from inf to 0.65708, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 2/100
# 6376/6376 [==============================] - 70s 11ms/step - loss: 0.5543 - acc: 0.7696 - val_loss: 0.5225 - val_acc: 0.7567
#
# Epoch 00002: val_loss improved from 0.65708 to 0.52254, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 3/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.4341 - acc: 0.8253 - val_loss: 0.5584 - val_acc: 0.7354
#
# Epoch 00003: val_loss did not improve from 0.52254
# Epoch 4/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.3713 - acc: 0.8507 - val_loss: 0.3742 - val_acc: 0.8489
#
# Epoch 00004: val_loss improved from 0.52254 to 0.37424, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 5/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.3681 - acc: 0.8518 - val_loss: 0.4095 - val_acc: 0.8376
#
# Epoch 00005: val_loss did not improve from 0.37424
# Epoch 6/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.3104 - acc: 0.8810 - val_loss: 0.3186 - val_acc: 0.8871
#
# Epoch 00006: val_loss improved from 0.37424 to 0.31861, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 7/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2869 - acc: 0.8908 - val_loss: 0.2980 - val_acc: 0.8846
#
# Epoch 00007: val_loss improved from 0.31861 to 0.29796, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 8/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2564 - acc: 0.9020 - val_loss: 0.2816 - val_acc: 0.8991
#
# Epoch 00008: val_loss improved from 0.29796 to 0.28157, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 9/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2561 - acc: 0.9032 - val_loss: 0.2964 - val_acc: 0.8777
#
# Epoch 00009: val_loss did not improve from 0.28157
# Epoch 10/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2285 - acc: 0.9108 - val_loss: 0.2611 - val_acc: 0.8966
#
# Epoch 00010: val_loss improved from 0.28157 to 0.26114, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 11/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2127 - acc: 0.9206 - val_loss: 0.2552 - val_acc: 0.9053
#
# Epoch 00011: val_loss improved from 0.26114 to 0.25521, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 12/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.2059 - acc: 0.9255 - val_loss: 0.2328 - val_acc: 0.9135
#
# Epoch 00012: val_loss improved from 0.25521 to 0.23280, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 13/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1914 - acc: 0.9301 - val_loss: 0.2218 - val_acc: 0.9241
#
# Epoch 00013: val_loss improved from 0.23280 to 0.22181, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 14/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.1788 - acc: 0.9406 - val_loss: 0.2231 - val_acc: 0.9185
#
# Epoch 00014: val_loss did not improve from 0.22181
# Epoch 15/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1676 - acc: 0.9453 - val_loss: 0.2203 - val_acc: 0.9122
#
# Epoch 00015: val_loss improved from 0.22181 to 0.22033, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 16/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1774 - acc: 0.9357 - val_loss: 0.2324 - val_acc: 0.9078
#
# Epoch 00016: val_loss did not improve from 0.22033
# Epoch 17/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1591 - acc: 0.9471 - val_loss: 0.2093 - val_acc: 0.9229
#
# Epoch 00017: val_loss improved from 0.22033 to 0.20931, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 18/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.1614 - acc: 0.9431 - val_loss: 0.2155 - val_acc: 0.9204
#
# Epoch 00018: val_loss did not improve from 0.20931
# Epoch 19/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1397 - acc: 0.9545 - val_loss: 0.2050 - val_acc: 0.9285
#
# Epoch 00019: val_loss improved from 0.20931 to 0.20501, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 20/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1369 - acc: 0.9540 - val_loss: 0.1959 - val_acc: 0.9323
#
# Epoch 00020: val_loss improved from 0.20501 to 0.19591, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 21/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1334 - acc: 0.9555 - val_loss: 0.2094 - val_acc: 0.9160
#
# Epoch 00021: val_loss did not improve from 0.19591
# Epoch 22/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1409 - acc: 0.9528 - val_loss: 0.1868 - val_acc: 0.9361
#
# Epoch 00022: val_loss improved from 0.19591 to 0.18680, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 23/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1246 - acc: 0.9617 - val_loss: 0.1976 - val_acc: 0.9304
#
# Epoch 00023: val_loss did not improve from 0.18680
# Epoch 24/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1242 - acc: 0.9600 - val_loss: 0.1800 - val_acc: 0.9361
#
# Epoch 00024: val_loss improved from 0.18680 to 0.17996, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 25/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.1217 - acc: 0.9600 - val_loss: 0.1723 - val_acc: 0.9411
#
# Epoch 00025: val_loss improved from 0.17996 to 0.17230, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 26/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1078 - acc: 0.9666 - val_loss: 0.1937 - val_acc: 0.9241
#
# Epoch 00026: val_loss did not improve from 0.17230
# Epoch 27/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.1087 - acc: 0.9677 - val_loss: 0.1708 - val_acc: 0.9373
#
# Epoch 00027: val_loss improved from 0.17230 to 0.17077, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 28/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1009 - acc: 0.9696 - val_loss: 0.1685 - val_acc: 0.9398
#
# Epoch 00028: val_loss improved from 0.17077 to 0.16853, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 29/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0981 - acc: 0.9699 - val_loss: 0.1829 - val_acc: 0.9335
#
# Epoch 00029: val_loss did not improve from 0.16853
# Epoch 30/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.1032 - acc: 0.9671 - val_loss: 0.1639 - val_acc: 0.9404
#
# Epoch 00030: val_loss improved from 0.16853 to 0.16389, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 31/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0958 - acc: 0.9705 - val_loss: 0.1666 - val_acc: 0.9429
#
# Epoch 00031: val_loss did not improve from 0.16389
# Epoch 32/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0904 - acc: 0.9724 - val_loss: 0.1732 - val_acc: 0.9429
#
# Epoch 00032: val_loss did not improve from 0.16389
# Epoch 33/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0880 - acc: 0.9726 - val_loss: 0.1727 - val_acc: 0.9398
#
# Epoch 00033: val_loss did not improve from 0.16389
# Epoch 34/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0855 - acc: 0.9738 - val_loss: 0.1563 - val_acc: 0.9492
#
# Epoch 00034: val_loss improved from 0.16389 to 0.15626, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 35/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0868 - acc: 0.9741 - val_loss: 0.2024 - val_acc: 0.9329
#
# Epoch 00035: val_loss did not improve from 0.15626
# Epoch 36/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0905 - acc: 0.9707 - val_loss: 0.1552 - val_acc: 0.9455
#
# Epoch 00036: val_loss improved from 0.15626 to 0.15520, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 37/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0772 - acc: 0.9776 - val_loss: 0.1547 - val_acc: 0.9480
#
# Epoch 00037: val_loss improved from 0.15520 to 0.15475, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 38/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0787 - acc: 0.9779 - val_loss: 0.1523 - val_acc: 0.9455
#
# Epoch 00038: val_loss improved from 0.15475 to 0.15235, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 39/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0713 - acc: 0.9810 - val_loss: 0.1485 - val_acc: 0.9486
#
# Epoch 00039: val_loss improved from 0.15235 to 0.14852, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 40/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0733 - acc: 0.9787 - val_loss: 0.1632 - val_acc: 0.9448
#
# Epoch 00040: val_loss did not improve from 0.14852
# Epoch 41/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0783 - acc: 0.9755 - val_loss: 0.1794 - val_acc: 0.9436
#
# Epoch 00041: val_loss did not improve from 0.14852
# Epoch 42/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0732 - acc: 0.9784 - val_loss: 0.1459 - val_acc: 0.9542
#
# Epoch 00042: val_loss improved from 0.14852 to 0.14589, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 43/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0657 - acc: 0.9809 - val_loss: 0.1466 - val_acc: 0.9505
#
# Epoch 00043: val_loss did not improve from 0.14589
# Epoch 44/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0624 - acc: 0.9824 - val_loss: 0.1491 - val_acc: 0.9473
#
# Epoch 00044: val_loss did not improve from 0.14589
# Epoch 45/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0584 - acc: 0.9832 - val_loss: 0.1470 - val_acc: 0.9530
#
# Epoch 00045: val_loss did not improve from 0.14589
# Epoch 46/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0652 - acc: 0.9821 - val_loss: 0.1418 - val_acc: 0.9567
#
# Epoch 00046: val_loss improved from 0.14589 to 0.14181, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 47/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0726 - acc: 0.9784 - val_loss: 0.1954 - val_acc: 0.9404
#
# Epoch 00047: val_loss did not improve from 0.14181
# Epoch 48/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0771 - acc: 0.9757 - val_loss: 0.1876 - val_acc: 0.9455
#
# Epoch 00048: val_loss did not improve from 0.14181
# Epoch 49/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0665 - acc: 0.9809 - val_loss: 0.1383 - val_acc: 0.9567
#
# Epoch 00049: val_loss improved from 0.14181 to 0.13830, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 50/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0599 - acc: 0.9826 - val_loss: 0.1539 - val_acc: 0.9492
#
# Epoch 00050: val_loss did not improve from 0.13830
# Epoch 51/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0582 - acc: 0.9831 - val_loss: 0.1548 - val_acc: 0.9480
#
# Epoch 00051: val_loss did not improve from 0.13830
# Epoch 52/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0519 - acc: 0.9859 - val_loss: 0.1449 - val_acc: 0.9536
#
# Epoch 00052: val_loss did not improve from 0.13830
# Epoch 53/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0470 - acc: 0.9878 - val_loss: 0.1382 - val_acc: 0.9542
#
# Epoch 00053: val_loss improved from 0.13830 to 0.13825, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 54/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0481 - acc: 0.9876 - val_loss: 0.1435 - val_acc: 0.9567
#
# Epoch 00054: val_loss did not improve from 0.13825
# Epoch 55/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0492 - acc: 0.9857 - val_loss: 0.1450 - val_acc: 0.9511
#
# Epoch 00055: val_loss did not improve from 0.13825
# Epoch 56/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0452 - acc: 0.9884 - val_loss: 0.1372 - val_acc: 0.9574
#
# Epoch 00056: val_loss improved from 0.13825 to 0.13716, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 57/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0457 - acc: 0.9890 - val_loss: 0.1384 - val_acc: 0.9561
#
# Epoch 00057: val_loss did not improve from 0.13716
# Epoch 58/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0410 - acc: 0.9900 - val_loss: 0.1377 - val_acc: 0.9567
#
# Epoch 00058: val_loss did not improve from 0.13716
# Epoch 59/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0468 - acc: 0.9868 - val_loss: 0.1457 - val_acc: 0.9542
#
# Epoch 00059: val_loss did not improve from 0.13716
# Epoch 60/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0419 - acc: 0.9876 - val_loss: 0.1395 - val_acc: 0.9567
#
# Epoch 00060: val_loss did not improve from 0.13716
# Epoch 61/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0422 - acc: 0.9884 - val_loss: 0.1311 - val_acc: 0.9599
#
# Epoch 00061: val_loss improved from 0.13716 to 0.13106, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 62/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0368 - acc: 0.9911 - val_loss: 0.1356 - val_acc: 0.9605
#
# Epoch 00062: val_loss did not improve from 0.13106
# Epoch 63/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0352 - acc: 0.9918 - val_loss: 0.1286 - val_acc: 0.9586
#
# Epoch 00063: val_loss improved from 0.13106 to 0.12857, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 64/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0329 - acc: 0.9931 - val_loss: 0.1523 - val_acc: 0.9536
#
# Epoch 00064: val_loss did not improve from 0.12857
# Epoch 65/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0329 - acc: 0.9922 - val_loss: 0.1299 - val_acc: 0.9624
#
# Epoch 00065: val_loss did not improve from 0.12857
# Epoch 66/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0336 - acc: 0.9920 - val_loss: 0.1359 - val_acc: 0.9599
#
# Epoch 00066: val_loss did not improve from 0.12857
# Epoch 67/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0296 - acc: 0.9937 - val_loss: 0.1473 - val_acc: 0.9567
#
# Epoch 00067: val_loss did not improve from 0.12857
# Epoch 68/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0343 - acc: 0.9925 - val_loss: 0.2276 - val_acc: 0.9361
#
# Epoch 00068: val_loss did not improve from 0.12857
# Epoch 69/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0368 - acc: 0.9909 - val_loss: 0.1349 - val_acc: 0.9592
#
# Epoch 00069: val_loss did not improve from 0.12857
# Epoch 70/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0272 - acc: 0.9945 - val_loss: 0.1354 - val_acc: 0.9624
#
# Epoch 00070: val_loss did not improve from 0.12857
# Epoch 71/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0293 - acc: 0.9940 - val_loss: 0.1820 - val_acc: 0.9480
#
# Epoch 00071: val_loss did not improve from 0.12857
# Epoch 72/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0376 - acc: 0.9896 - val_loss: 0.1849 - val_acc: 0.9329
#
# Epoch 00072: val_loss did not improve from 0.12857
# Epoch 73/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0298 - acc: 0.9950 - val_loss: 0.1342 - val_acc: 0.9592
#
# Epoch 00073: val_loss did not improve from 0.12857
# Epoch 74/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0252 - acc: 0.9958 - val_loss: 0.1520 - val_acc: 0.9592
#
# Epoch 00074: val_loss did not improve from 0.12857
# Epoch 75/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.0294 - acc: 0.9926 - val_loss: 0.1278 - val_acc: 0.9643
#
# Epoch 00075: val_loss improved from 0.12857 to 0.12783, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 76/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0225 - acc: 0.9958 - val_loss: 0.1464 - val_acc: 0.9561
#
# Epoch 00076: val_loss did not improve from 0.12783
# Epoch 77/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0269 - acc: 0.9953 - val_loss: 0.1357 - val_acc: 0.9630
#
# Epoch 00077: val_loss did not improve from 0.12783
# Epoch 78/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.0237 - acc: 0.9962 - val_loss: 0.1346 - val_acc: 0.9618
#
# Epoch 00078: val_loss did not improve from 0.12783
# Epoch 79/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0223 - acc: 0.9962 - val_loss: 0.1277 - val_acc: 0.9643
#
# Epoch 00079: val_loss improved from 0.12783 to 0.12768, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 80/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0196 - acc: 0.9975 - val_loss: 0.1404 - val_acc: 0.9630
#
# Epoch 00080: val_loss did not improve from 0.12768
# Epoch 81/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0248 - acc: 0.9940 - val_loss: 0.1327 - val_acc: 0.9643
#
# Epoch 00081: val_loss did not improve from 0.12768
# Epoch 82/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0210 - acc: 0.9969 - val_loss: 0.1509 - val_acc: 0.9555
#
# Epoch 00082: val_loss did not improve from 0.12768
# Epoch 83/100
# 6376/6376 [==============================] - 73s 11ms/step - loss: 0.0293 - acc: 0.9939 - val_loss: 0.1497 - val_acc: 0.9567
#
# Epoch 00083: val_loss did not improve from 0.12768
# Epoch 84/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0201 - acc: 0.9973 - val_loss: 0.1301 - val_acc: 0.9630
#
# Epoch 00084: val_loss did not improve from 0.12768
# Epoch 85/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0165 - acc: 0.9980 - val_loss: 0.1257 - val_acc: 0.9687
#
# Epoch 00085: val_loss improved from 0.12768 to 0.12573, saving model to /content/drive/My Drive/CS682 Project/Final/Models/LampNet_Baseline5_1(cb)_128x128.h5
# Epoch 86/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0159 - acc: 0.9989 - val_loss: 0.1377 - val_acc: 0.9605
#
# Epoch 00086: val_loss did not improve from 0.12573
# Epoch 87/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0176 - acc: 0.9975 - val_loss: 0.1559 - val_acc: 0.9567
#
# Epoch 00087: val_loss did not improve from 0.12573
# Epoch 88/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0199 - acc: 0.9959 - val_loss: 0.1355 - val_acc: 0.9643
#
# Epoch 00088: val_loss did not improve from 0.12573
# Epoch 89/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0142 - acc: 0.9989 - val_loss: 0.1379 - val_acc: 0.9605
#
# Epoch 00089: val_loss did not improve from 0.12573
# Epoch 90/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0146 - acc: 0.9986 - val_loss: 0.1316 - val_acc: 0.9636
#
# Epoch 00090: val_loss did not improve from 0.12573
# Epoch 91/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0134 - acc: 0.9991 - val_loss: 0.1312 - val_acc: 0.9636
#
# Epoch 00091: val_loss did not improve from 0.12573
# Epoch 92/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0145 - acc: 0.9989 - val_loss: 0.1480 - val_acc: 0.9618
#
# Epoch 00092: val_loss did not improve from 0.12573
# Epoch 93/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0147 - acc: 0.9991 - val_loss: 0.1374 - val_acc: 0.9618
#
# Epoch 00093: val_loss did not improve from 0.12573
# Epoch 94/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0132 - acc: 0.9989 - val_loss: 0.1281 - val_acc: 0.9643
#
# Epoch 00094: val_loss did not improve from 0.12573
# Epoch 95/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0134 - acc: 0.9986 - val_loss: 0.1304 - val_acc: 0.9636
#
# Epoch 00095: val_loss did not improve from 0.12573
# Epoch 96/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0107 - acc: 0.9998 - val_loss: 0.1301 - val_acc: 0.9661
#
# Epoch 00096: val_loss did not improve from 0.12573
# Epoch 97/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0103 - acc: 0.9997 - val_loss: 0.1336 - val_acc: 0.9649
#
# Epoch 00097: val_loss did not improve from 0.12573
# Epoch 98/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0099 - acc: 0.9995 - val_loss: 0.1286 - val_acc: 0.9630
#
# Epoch 00098: val_loss did not improve from 0.12573
# Epoch 99/100
# 6376/6376 [==============================] - 71s 11ms/step - loss: 0.0096 - acc: 0.9998 - val_loss: 0.1360 - val_acc: 0.9630
#
# Epoch 00099: val_loss did not improve from 0.12573
# Epoch 100/100
# 6376/6376 [==============================] - 72s 11ms/step - loss: 0.0090 - acc: 0.9997 - val_loss: 0.1325 - val_acc: 0.9643
#
# Epoch 00100: val_loss did not improve from 0.12573
# Saved training history!

# %%
print("Best val_loss = {}\nBest val_acc = {}".format(min(history.history['val_loss']), max(history.history['val_acc'])))
# Out:
# Best val_loss = 0.12573122518563346
# Best val_acc = 0.968652038439688

# %%
title_font = {'fontname':'Times', 'size':'16', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} # Bottom vertical alignment for more space
axis_font = {'fontname':'Times', 'size':'14'}


# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy', **title_font)
plt.ylabel('accuracy', **axis_font)
plt.xlabel('epoch', **axis_font)
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# plt.savefig(results_path + 'Accuracy plot.pdf')
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', **title_font)
plt.ylabel('loss', **axis_font)
plt.xlabel('epoch', **axis_font)
plt.legend(['train', 'val'], loc='upper right')
plt.show()
# plt.savefig(results_path + 'Loss plot.pdf')
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# findfont: Font family ['Times'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times'] not found. Falling back to DejaVu Sans.

# %%
print("############### Stats for fully trained model ###############")
model = load_model(models_path + 'LampNet_Baseline2_1_128x128.h5')

test_scores = model.evaluate(X_test, y_test, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
y_preds1 = model.predict(X_test)
ctest, preds = np.argmax(y_test, axis = 1), np.argmax(y_preds1, axis = 1)
print("Confusion matrix : ")
print(confusion_matrix(ctest, preds))

print("############### Stats for CallBack model ###############")
model = load_model(models_path + 'LampNet_Baseline2_1(cb)_128x128.h5')

test_scores = model.evaluate(X_test, y_test, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
y_preds2 = model.predict(X_test)
ctest, preds = np.argmax(y_test, axis = 1), np.argmax(y_preds2, axis = 1)
print("Confusion matrix : ")
print(confusion_matrix(ctest, preds))
# Out:
# ############### Stats for fully trained model ###############
# Test loss: 0.1395965718195677
# Test accuracy: 0.9653875094055681
# Confusion matrix :
# [[631  11  10]
#  [ 22 953   8]
#  [ 21  20 982]]
# ############### Stats for CallBack model ###############
# Test loss: 0.12741223378539676
# Test accuracy: 0.9661399548532731
# Confusion matrix :
# [[633   7  12]
#  [ 27 948   8]
#  [ 22  14 987]]

# %%
y_preds1 = np.argmax(y_preds1, axis = 1)
y_preds2 = np.argmax(y_preds2, axis = 1)
y_test = np.argmax(y_test, axis = 1)

# %%
print("############### Classification report for Fully trained model ###############")
print(classification_report(y_test, y_preds1, target_names = ['Background', 'Fish', 'Lamprey']) )

print("############### Classification report for CallBack model ###############")
print(classification_report(y_test, y_preds2, target_names = ['Background', 'Fish', 'Lamprey']) )
# Out:
# ############### Classification report for Fully trained model ###############
#               precision    recall  f1-score   support
#
#   Background       0.93      0.98      0.96       652
#         Fish       0.98      0.97      0.97       983
#      Lamprey       0.99      0.96      0.97      1023
#
#     accuracy                           0.97      2658
#    macro avg       0.97      0.97      0.97      2658
# weighted avg       0.97      0.97      0.97      2658
#
# ############### Classification report for CallBack model ###############
#               precision    recall  f1-score   support
#
#   Background       0.94      0.98      0.96       652
#         Fish       0.98      0.97      0.97       983
#      Lamprey       0.99      0.97      0.98      1023
#
#     accuracy                           0.97      2658
#    macro avg       0.97      0.97      0.97      2658
# weighted avg       0.97      0.97      0.97      2658

# %%
y_test[0], y_preds2
# Out:
# 1

# %%
wrong_prediction = []
for i in range(len(X_test)):
  if y_test[i]==2 and y_preds2[i]!=2:
    plt.figure()
    plt.imshow(((X_test[i]*std_pixel)+mean_pixel).reshape(128, 128, 3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
y_probs = model.predict_proba(X_test)
y_test = to_categorical(y_test)

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

fpr = dict()
tpr = dict()
roc_auc = dict()
class_score = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    class_score[i] = roc_auc_score(y_test[:, i], y_probs[:, i])
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure(figsize=(10, 7))
lw = 2
plt.plot(fpr[2], tpr[2], color='orange',
         lw=lw, label='ROC curve for Lamprey class(area = %0.2f)' % roc_auc[2])
plt.plot(fpr[1], tpr[1], color='red',
         lw=lw, label='ROC curve for Fish class (area = %0.2f)' % roc_auc[1])
plt.plot(fpr[0], tpr[0], color='green',
         lw=lw, label='ROC curve Background class(area = %0.2f)' % roc_auc[0])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', family = 'sans-serif', size = 18)
plt.ylabel('True Positive Rate',  family = 'sans-serif', size = 18)
plt.title('ROC curve for each class', family = 'serif', size = 20, weight = 'normal')
plt.xticks(family = 'sans-serif', size = 16)
plt.yticks(family = 'sans-serif', size = 16)
plt.legend(loc="lower right", prop={'size': 17})
plt.show()
print(class_score)
# Out:
# {0: 0.9944170555817212, 1: 0.9969535840634064, 2: 0.9970303807533757}

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(10,7)})
sns.lineplot(fpr[2], tpr[2], color='orange',
         lw=lw, label='ROC curve for Lamprey class(area = %0.2f)' % roc_auc[2])
sns.lineplot( fpr[1], tpr[1], color='red',
         lw=lw, label='ROC curve for Fish class (area = %0.2f)' % roc_auc[1])
sns.lineplot(fpr[0], tpr[0], color='green',
         lw=lw, label='ROC curve Background class(area = %0.2f)' % roc_auc[0])
sns.lineplot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.legend(loc="lower right", prop={'size': 17})
plt.xlabel('False Positive Rate', family = 'sans-serif', size = 18)
plt.ylabel('True Positive Rate',  family = 'sans-serif', size = 18)
plt.title('ROC curve for each class', family = 'serif', size = 20, weight = 'normal')
plt.xticks(family = 'sans-serif', size = 16)
plt.yticks(family = 'sans-serif', size = 16)
# ax.xlim([0.0, 1.0])
# ax.ylim([0.0, 1.05])
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text yticklabel objects>)

# %%
print("ROC-AUC score for the model %.3f" %(roc_auc_score(y_test, y_probs)))
# Out:
# ROC-AUC score for the model 0.996

# %%
# keras.utils.plot_model(model, 'my_first_model.png')

# %%
# keras.utils.plot_model(model, 'my_first_model_with_shape_info.png', show_shapes=True)

# %%
plt.figure()
plt.imshow(((X_test[101]*std_pixel)+mean_pixel).reshape(128, 128, 3))

# %%
from keras import models

layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(input=model.input, output=layer_outputs)
# activations = activation_model.predict(((X_test[101]-mean_pixel)/std_pixel).reshape(1,128,128,3))
activations = activation_model.predict((X_test[101]).reshape(1,128,128,3))

plt.figure(figsize=(1,1))
first_layer_activation = activations[0]
plt.matshow(first_layer_activation[0, :, :, 9], cmap='viridis',)

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
