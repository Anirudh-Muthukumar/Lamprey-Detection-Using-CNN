# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import os, cv2
from PIL import Image, ImageOps
from tqdm import tqdm
import numpy as np
import math
import timeit
from random import shuffle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras import backend as K
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

os.environ['KMP_DUPLICATE_LIB_OK']='True' # to fix kernel dead and restarting issue

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Setting root directory for the user

# %%
check_dir = os.getcwd() + '/drive/My Drive/'
if 'Academics' in os.listdir(check_dir): # Niraj drive
  root_dir = '/content/drive/My Drive/Academics/Sem1/682/'
else: # Anirudh drive
  root_dir = '/content/drive/My Drive/'

# %%
dataset_path = root_dir + 'CS682 Project/Milestone/Crop_Data/'
save_path = root_dir + 'CS682 Project/Milestone/Resize_Data/'
data_list = ['Background', 'Fish', 'Lamprey']
preprocessing = False

new_size = 128

for i, data in enumerate(data_list):
  # print(i, data)
  files = os.listdir(dataset_path + data)
  # print('len', len(files))
  # if not os.path.exists(save_path + 'data_{}/{}/'.format(new_size, data)):
  #       os.mkdir(save_path + 'data_{}/{}/'.format(new_size, data))
  for j, file in enumerate(files):
    if j%10 == 0:
      print(i, j)
    if file == '.DS_Store':
      pass
    else:
      # print('Image path:', data_dir + data + '/' + file)
      # print(i, j)
      img = Image.open(dataset_path + data + '/' + file)
      img = img.resize((new_size, new_size))
      
      img.save(save_path + 'data_{}/{}/{}_27_1.png'.format(new_size, data, file), "PNG")
# Out:
# 0 0
# 0 10
# 0 20
# 0 30
# 0 40
# 0 50
# 0 60
# 0 70
# 0 80
# 0 90
# 0 100
# 0 110
# 0 120
# 0 130
# 0 140
# 0 150
# 0 160
# 0 170
# 0 180
# 0 190
# 0 200
# 0 210
# 0 220
# 0 230
# 0 240
# 0 250
# 0 260
# 0 270
# 0 280
# 0 290
# 0 300
# 0 310
# 0 320
# 0 330
# 0 340
# 0 350
# 0 360
# 0 370
# 0 380
# 0 390
# 0 400
# 0 410
# 0 420
# 0 430
# 0 440
# 0 450
# 0 460
# 0 470
# 0 480
# 0 490
# 0 500
# 0 510
# 0 520
# 0 530
# 0 540
# 0 550
# 0 560
# 0 570
# 0 580
# 0 590
# 0 600
# 0 610
# 0 620
# 0 630
# 0 640
# 0 650
# 0 660
# 0 670
# 0 680
# 0 690
# 0 700
# 0 710
# 0 720
# 0 730
# 0 740
# 0 750
# 0 760
# 0 770
# 0 780
# 0 790
# 0 800
# 0 810
# 0 820
# 0 830
# 0 840
# 0 850
# 0 860
# 0 870
# 0 880
# 0 890
# 0 900
# 0 910
# 0 920
# 0 930
# 0 940
# 0 950
# 0 960
# 0 970
# 0 980
# 0 990
# 0 1000
# 0 1010
# 0 1020
# 0 1030
# 0 1040
# 1 0
# 1 10
# 1 20
# 1 30
# 1 40
# 1 50
# 1 60
# 1 70
# 1 80
# 1 90
# 1 100
# 1 110
# 1 120
# 1 130
# 1 140
# 1 150
# 1 160
# 1 170
# 1 180
# 1 190
# 1 200
# 1 210
# ...
